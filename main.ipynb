# %%
from data.dataset import train_loader, val_loader, test_loader

# %%
import matplotlib.pyplot as plt
from data.dataset import train_loader, val_loader, test_loader
for i, batch in enumerate(val_loader):
    plt.subplot(3,3,i+1)
    plt.axis('off')
    plt.imshow(batch['image'][0][0], cmap='gray', vmin=0, vmax=255)
    plt.title(f"Label:{batch['label'][0]}")
    if i == 8:
        break
# Out:
# ['data/KneeOsteoarthritisDataset\\val\\0\\9024900R.png']
