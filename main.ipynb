# %%
import matplotlib.pyplot as plt
from data.dataset import val_loader, train_loader


for i, batch in enumerate(train_loader):
    plt.figure(figsize=(12,12))
    for j in range(len(batch['label'])):
        plt.subplot(8,8,j+1)
        plt.axis('off')
        plt.imshow(batch['image'][j][0], cmap='gray')
        plt.imshow(batch['image_segmented'][j,0], alpha=0.3)
        plt.title("LABEL: "+str(batch['label'][j].item()))
    plt.show()
    break

for i, batch in enumerate(val_loader):
    plt.figure(figsize=(12,12))
    for j in range(len(batch['label'])):
        plt.subplot(8,8,j+1)
        plt.axis('off')
        plt.imshow(batch['image'][j][0], cmap='gray')
        plt.imshow(batch['image_segmented'][j,0], alpha=0.3)
        plt.title("LABEL: "+str(batch['label'][j].item()))
    plt.show()
    break
# Out:
# C:\Users\muham\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\muham\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
